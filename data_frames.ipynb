# %%
import pandas as pd

data = {
    "name": ["shracvan", "shradha", "palak"],
    "age": [19, 20, 19],
    "salary": [35000, 45000, 20000]
}

a = pd.DataFrame(data)
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       3 data = {
#       4     "name": ["shracvan", "shradha", "palak"],
#       5     "age": [19, 20, 19],
#       6     "salary": [35000, 45000, 20000]
#       7 }
#       9 a = pd.DataFrame(data)
#
# File c:\python11\Lib\site-packages\pandas\__init__.py:26
#      24 for _dependency in _hard_dependencies:
#      25     try:
# ---> 26         __import__(_dependency)
#      27     except ImportError as _e:  # pragma: no cover
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File c:\Users\Mansi\OneDrive\Desktop\python\pythonProject2\numpy.py:3
#       1 import numpy as np
# ----> 3 arr = np.array([10, 20, 30, 40])
#       4 print(arr)
#
# AttributeError: partially initialized module 'numpy' has no attribute 'array' (most likely due to a circular import)
